# %%
# Import Libraries
import sys
from pathlib import Path
import geopandas as gpd

# Add src to path
sys.path.insert(0, str(Path.cwd() / 'src'))

# Import our library functions
from src.config import CityConfig
from src.building_processor import load_buildings, process_buildings
from src.poi_processor import load_pois, process_pois
from src.spatial_matcher import match_pois_to_buildings, join_matches_to_pois
from src.heuristics import apply_heuristics_to_pois
from src.trip_generator import (
    create_trip_generators,
    save_trip_generators,
    print_trip_gen_summary
)

# --- Configuration ---
CITY = 'brooklyn'
config = CityConfig(city_name=CITY)
place_name = "Brooklyn, New York, USA"

# Verbosity control - set to False for minimal output
VERBOSE = True  # Set to False for only critical messages and high-level stats

CACHE_DIR = Path("cache")
CACHE_DIR.mkdir(exist_ok=True)
USE_CACHE = True  # Set to False to force re-download

# Cache and output file paths
BUILDINGS_CACHE = CACHE_DIR / f"buildings_raw_{CITY}.geojson"
POIS_CACHE = CACHE_DIR / f"pois_raw_{CITY}.geojson"
BUILDINGS_OUT = Path('data') / f"buildings_{CITY}.geojson"
TRIP_GENERATORS_OUT_GEOJSON = Path('data') / f"trip_generators_{CITY}.geojson"
TRIP_GENERATORS_OUT_CSV = Path('data') / f"trip_generators_{CITY}.csv"

# %%
# Load and Process Buildings

# Load buildings
buildings_raw = load_buildings(
    place_name=place_name,
    cache_path=BUILDINGS_CACHE,
    use_cache=USE_CACHE,
    verbose=VERBOSE
)

# Process buildings to calculate square footage
buildings_gdf = process_buildings(buildings_raw, config, verbose=VERBOSE)

# Display sample if verbose
if VERBOSE:
    print("\nSample buildings data:")
    print(buildings_gdf[['building_id', 'building', 'footprint_sqft', 'estimated_floors', 'total_sqft']].head(10))
# Out:
# Loading buildings from cache: cache/buildings_raw_brooklyn.geojson
# Loaded 331,538 buildings
# WARNING: 63 buildings exceed 1M sqft
#   Large buildings stats: max=4,670,733 sqft, mean=1,573,729 sqft
#
# Total buildings with warnings: 63 (0.0%)
# Buildings processed: 331,538
#
# Sample buildings data:
#    building_id    building  footprint_sqft  estimated_floors     total_sqft
# 0            0         yes    33487.362541                 3  100462.087623
# 1            1         yes    10160.424650                 5   50802.123248
# 2            2         yes    10294.479685                 5   51472.398427
# 3            3         yes     9558.502166                 5   47792.510831
# 4            4         yes     6745.779850                 6   40474.679101
# 5            5         yes    13402.631808                11  147428.949889
# 6            6  apartments     8986.979593                 6   53921.877561
# 7            7         yes    16507.082635                 6   99042.495808
# 8            8      public    30301.440341                15  454521.605118
# 9            9         yes     5634.379375                 5   28171.896876

# %%
# Load and Process POIs

# Load POIs
pois_raw = load_pois(
    place_name=place_name,
    cache_path=POIS_CACHE,
    use_cache=USE_CACHE,
    verbose=VERBOSE
)

# Process POIs (filter and get centroids)
pois_gdf = process_pois(
    pois_raw,
    filter_non_trip_generators=True,
    verbose=VERBOSE
)

# Show POI type distribution if verbose
if VERBOSE:
    for col in ['amenity', 'shop', 'office', 'leisure', 'tourism', 'public_transport']:
        if col in pois_gdf.columns:
            counts = pois_gdf[col].dropna().value_counts().head(10)
            if len(counts) > 0:
                print(f"\nTop 10 {col} types:")
                print(counts)
# Out:
# Loading POIs from cache: cache/pois_raw_brooklyn.geojson
# Loaded 56,636 POIs
# POIs before filtering: 56,636
# POIs after filtering: 29,743
# POIs processed: 29,743
#
# Top 10 amenity types:
# amenity
# restaurant          1806
# fast_food           1416
# place_of_worship     984
# cafe                 763
# school               593
# bar                  469
# pharmacy             291
# bank                 251
# dentist              211
# clinic               190
# Name: count, dtype: int64
#
# Top 10 shop types:
# shop
# convenience      1145
# hairdresser       642
# beauty            557
# clothes           487
# supermarket       351
# laundry           350
# alcohol           283
# car_repair        253
# deli              231
# variety_store     222
# Name: count, dtype: int64
#
# Top 10 office types:
# office
# company         293
# estate_agent    188
# lawyer          136
# insurance        73
# tax_advisor      73
# government       58
# accountant       57
# financial        39
# construction     35
# travel_agent     35
# Name: count, dtype: int64
#
# Top 10 leisure types:
# leisure
# pitch               1567
# playground           627
# park                 485
# fitness_centre       221
# track                109
# sports_centre        108
# dog_park              35
# dance                 12
# nature_reserve         8
# amusement_arcade       6
# Name: count, dtype: int64
#
# Top 10 tourism types:
# tourism
# artwork        144
# information    105
# hotel           84
# gallery         64
# attraction      62
# picnic_site     49
# viewpoint       25
# museum          24
# motel            8
# guest_house      4
# Name: count, dtype: int64
#
# Top 10 public_transport types:
# public_transport
# platform         3895
# stop_position    3019
# station           179
# no                  2
# dispatcher          1
# Name: count, dtype: int64

# %%
# Match POIs to Buildings

# Perform spatial matching
matches_df = match_pois_to_buildings(buildings_gdf, pois_gdf, verbose=VERBOSE)

# Join matches back to POIs
pois_matched = join_matches_to_pois(pois_gdf, matches_df, verbose=VERBOSE)
# Out:
# Matching POIs to buildings using spatial join...
#   Building spatial index for faster matching...
# Matched 18,694 POIs to buildings (62.9%)
# POIs with building matches: 18,694

# %%
# Apply Brooklyn Heuristics for Space Allocation

# Apply heuristics to allocate space
processed_pois_df = apply_heuristics_to_pois(pois_matched, buildings_gdf, verbose=VERBOSE)

# Summary statistics if verbose
if VERBOSE:
    import pandas as pd
    remaining_flags = processed_pois_df.get('is_remaining')
    if isinstance(remaining_flags, pd.Series):
        remaining_mask = remaining_flags.fillna(False).infer_objects(copy=False).astype(bool)
    else:
        remaining_mask = pd.Series(False, index=processed_pois_df.index)

    actual_pois = processed_pois_df[~remaining_mask]
    remaining_pois = processed_pois_df[remaining_mask]

    print(f"\nSpace Allocation Summary:")
    print(f"  Actual POI sqft: {actual_pois['poi_sqft'].sum():,.0f}")
    print(f"  Remaining/upper floor sqft: {remaining_pois['poi_sqft'].sum():,.0f}")
    print(f"  Total allocated: {processed_pois_df['poi_sqft'].sum():,.0f}")

    # Verify no double-counting
    print(f"\nDouble-count check (sample buildings with multiple POIs):")
    multi_poi_buildings = processed_pois_df.groupby('building_id').filter(lambda x: len(x) > 1)
    if len(multi_poi_buildings) > 0:
        sample_check = multi_poi_buildings.groupby('building_id').agg({
            'poi_sqft': 'sum',
            'building_total_sqft': 'first'
        }).head(5)
        sample_check['ratio'] = sample_check['poi_sqft'] / sample_check['building_total_sqft']
        print(sample_check)
# Out:
# Processed POIs (including inferred remaining): 27,928
#
# INFO: Found 297 unknown POI type(s) (using defaults):
#   amenity: acting_school
#   amenity: animal_boarding
#   amenity: animal_shelter
#   amenity: animal_training
#   amenity: barber
#   amenity: beauty_school
#   amenity: bureau_de_change
#   amenity: car_rental
#   amenity: car_sharing
#   amenity: car_wash
#   amenity: charging_station
#   amenity: childcare
#   amenity: concert_hall
#   amenity: courthouse
#   amenity: crematorium
#   amenity: dancing_school
#   amenity: disused:bar
#   amenity: dog
#   amenity: dog_groomer
#   amenity: dojo
#   amenity: driving_school
#   amenity: events_venue
#   amenity: fire_station
#   amenity: first_aid_school
#   amenity: fortune_teller
#   amenity: fuel
#   amenity: gambling
#   amenity: hookah_lounge
#   amenity: internet_cafe
#   amenity: karaoke_box
#   amenity: language_school
#   amenity: mailroom
#   amenity: marketplace
#   amenity: meditation_centre
#   amenity: monastery
#   amenity: money_transfer
#   amenity: motorcycle_parking
#   amenity: music_school
#   amenity: music_venue
#   amenity: office
#   amenity: parcel_locker
#   amenity: payment_centre
#   amenity: police
#   amenity: post_depot
#   amenity: prep_school
#   amenity: prison
#   amenity: public_bath
#   amenity: radio station
#   amenity: shoe
#   amenity: slaughterhouse
#   amenity: social_centre
#   amenity: social_facility
#   amenity: stage
#   amenity: store
#   amenity: stripclub
#   amenity: studio
#   amenity: taxi
#   amenity: towing
#   amenity: townhall
#   amenity: training
#   amenity: tutoring
#   amenity: vacant
#   amenity: waste_transfer_station
#   leisure: park
#   leisure: playground
#   leisure: sauna
#   leisure: stadium
#   office: accountant
#   office: administrative
#   office: advertising_agency
#   office: architect
#   office: association
#   office: bail_bond_agent
#   office: cemetery
#   office: charity
#   office: construction
#   office: construction_company
#   office: constuction
#   office: consulting
#   office: courier
#   office: coworking
#   office: design
#   office: educational_institution
#   office: electrician
#   office: emergency
#   office: employment_agency
#   office: energy_supplier
#   office: engineer
#   office: estate_agent
#   office: exterminator
#   office: financial
#   office: financial_advisor
#   office: graphic_design
#   office: healthcare
#   office: home_care
#   office: interior_decoration
#   office: interior_design
#   office: it
#   office: labour_union
#   office: landscape_architect
#   office: landscaping
#   office: logistics
#   office: marina
#   office: medical
#   office: military_recruitment
#   office: money_transfer
#   office: mortage_broker
#   office: moving_company
#   office: multiservice
#   office: newspaper
#   office: ngo
#   office: nursing_service
#   office: physician
#   office: political_party
#   office: private_investigator
#   office: property_management
#   office: public_transport
#   office: publisher
#   office: religion
#   office: research
#   office: security
#   office: security_training
#   office: skill_share
#   office: tax_advisor
#   office: taxi
#   office: telecommunication
#   office: therapist
#   office: travel_agent
#   office: tutor
#   office: tutoring
#   office: union
#   shop: anime
#   shop: antiques
#   shop: appliance
#   shop: aquarium
#   shop: art
#   shop: baby_goods
#   shop: bag
#   shop: bathroom_furnishing
#   shop: beauty_supplies
#   shop: beauty_supply
#   shop: bed
#   shop: beverages
#   shop: bicycle
#   shop: boat
#   shop: boat_repair
#   shop: boutique
#   shop: bridal
#   shop: bus_repair
#   shop: camera
#   shop: candles
#   shop: cannabis
#   shop: car
#   shop: car_detail
#   shop: car_modification
#   shop: car_parts
#   shop: car_repair
#   shop: carpet
#   shop: carpet_cleaning
#   shop: charity
#   shop: cheese
#   shop: chemist
#   shop: chocolate
#   shop: coffee
#   shop: collector
#   shop: computer
#   shop: computer_repair
#   shop: con
#   shop: confectionery
#   shop: convenience;e-cigarette
#   shop: cosmetics
#   shop: craft
#   shop: curtain
#   shop: doors
#   shop: dry_cleaning;tailor
#   shop: e-bike
#   shop: e-cigarette
#   shop: e_scooter
#   shop: electrical
#   shop: erotic
#   shop: estate_agent
#   shop: fabric
#   shop: farm
#   shop: fashion_accessories
#   shop: flooring
#   shop: florist
#   shop: food
#   shop: frame
#   shop: fuel
#   shop: funeral_directors
#   shop: games
#   shop: garden_centre
#   shop: general
#   shop: glaziery
#   shop: granite;marble
#   shop: grocery
#   shop: hairdresser_supply
#   shop: health_food
#   shop: hearing_aids
#   shop: herbalist
#   shop: household_linen
#   shop: houseware
#   shop: interior_decoration
#   shop: kiosk
#   shop: kitchen
#   shop: knives
#   shop: lighting
#   shop: linen
#   shop: livestock
#   shop: locksmith
#   shop: lumber
#   shop: massage
#   shop: medical_supply
#   shop: mobile_phone_accessories
#   shop: mobile_phone_repair
#   shop: money_lender
#   shop: motorcycle
#   shop: motorcycle_repair
#   shop: music
#   shop: musical_instrument
#   shop: newsagent
#   shop: nutrition_supplements
#   shop: outdoor
#   shop: paint
#   shop: party
#   shop: pasta
#   shop: pastry
#   shop: pawnbroker
#   shop: perfumery
#   shop: pest_control
#   shop: pet
#   shop: pet_grooming
#   shop: pet_grooming;pet
#   shop: photo
#   shop: photo_studio
#   shop: printer_ink
#   shop: printing
#   shop: religion
#   shop: rental
#   shop: repair
#   shop: restaurant_supply
#   shop: safety_equipment
#   shop: salon
#   shop: seafood
#   shop: second_hand
#   shop: security
#   shop: sewing
#   shop: shipping
#   shop: shoe_repair
#   shop: skate
#   shop: smoke
#   shop: soap
#   shop: spices
#   shop: sports
#   shop: stationery
#   shop: stone
#   shop: storage_rental
#   shop: tailor
#   shop: tattoo
#   shop: tattoo_removal
#   shop: tea
#   shop: telecommunication
#   shop: ticket
#   shop: tiles
#   shop: tobacco
#   shop: tool_hire
#   shop: tool_repair
#   shop: toys
#   shop: trade
#   shop: travel_agency
#   shop: trophy
#   shop: truck
#   shop: truck_repair
#   shop: tyres
#   shop: vacant
#   shop: vacuum_cleaner
#   shop: variety_store
#   shop: video
#   shop: video_games
#   shop: watches
#   shop: water
#   shop: weapons
#   shop: wholesale
#   shop: wigs
#   shop: window_blind
#   shop: wool
#   tourism: apartment
#   tourism: aquarium
#   tourism: artwork
#   tourism: attraction
#   tourism: gallery
#   tourism: historic
#   tourism: information
#   tourism: motel
#   tourism: theme_park
#   tourism: viewpoint
#   unknown: unknown
#
# Space Allocation Summary:
#   Actual POI sqft: 238,461,724
#   Remaining/upper floor sqft: 166,276,695
#   Total allocated: 404,738,418
#
# Double-count check (sample buildings with multiple POIs):
#                  poi_sqft  building_total_sqft  ratio
# building_id
# 8            4.545216e+05         4.545216e+05    1.0
# 12           8.454686e+04         8.454686e+04    1.0
# 22           4.348655e+04         4.348655e+04    1.0
# 28           1.299619e+06         1.299619e+06    1.0
# 33           9.902837e+04         9.902837e+04    1.0
# /var/folders/0q/g6bf_xks01543mczt656f8nc0000gn/T/ipykernel_77778/2892452045.py:11: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   remaining_mask = remaining_flags.fillna(False).infer_objects(copy=False).astype(bool)

# %%
# Create and Save Final Trip Generator Dataset

# This function now handles the unified creation and unit conversion
trip_generators_gdf = create_trip_generators(processed_pois_df, buildings_gdf, config, verbose=VERBOSE)

# Print summary with trip generation units if verbose
if VERBOSE:
    print_trip_gen_summary(trip_generators_gdf)

# Save the final trip generator files
save_trip_generators(
    trip_generators_gdf,
    geojson_path=TRIP_GENERATORS_OUT_GEOJSON,
    csv_path=TRIP_GENERATORS_OUT_CSV,
    verbose=VERBOSE
)

# Save the processed buildings file as well
buildings_gdf.to_file(BUILDINGS_OUT, driver="GeoJSON")
if VERBOSE:
    print(f"Saved processed buildings to: {BUILDINGS_OUT}")

print(f"\nWorkflow complete!")
# Out:
# Creating trip generators using optimized processing...
# Buildings with POIs: 14,201
# Buildings without POI: 317,337
# /Users/dpbirge/GITHUB/custom_notebooks/4step/src/trip_generator.py:78: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   is_remaining = remaining_series.fillna(False).infer_objects(copy=False).astype(bool)
# Converting to trip generation units...
# Trip Generators Created: 345,265 generators, 2,058,645,066 total sqft
#
# === Detailed Trip Generator Dataset ===
# Total generators: 345,265
# Total sqft: 2,058,645,066
#
# By Source:
#   building_inferred: 317,337.0 generators, 1,653,906,648 sqft
#   inferred_remaining: 10,398.0 generators, 166,276,695 sqft
#   osm_poi: 17,530.0 generators, 238,461,724 sqft
#
# Top 15 Trip Generation Categories:
#                                                     count   total_units  \
# trip_gen_category
# Residential (3 or more floors)                     325914  1.724654e+06
# Public School (Students)                              772  5.902861e+05
# Cineplex                                               55  3.981816e+05
# Local Retail                                        11450  1.098750e+05
# Office (multi-tenant type building)                  1276  3.667163e+04
# Medical Office                                        565  2.616197e+04
# Hotel                                                  93  1.669549e+04
# Daycare (Children)                                    161  1.467494e+04
# Destination Retail                                     71  1.089944e+04
# Health Club                                           266  9.791112e+03
# Academic University                                    44  8.498971e+03
# Sit Down/High Turnover Restaurant                    2823  6.611422e+03
# Supermarket                                           337  3.286296e+03
# Museum                                                 23  3.138258e+03
# Fast Food Restaurant without Drive Through Window    1297  2.497039e+03
#
#                                                   unit_type
# trip_gen_category
# Residential (3 or more floors)                           DU
# Public School (Students)                           students
# Cineplex                                              seats
# Local Retail                                        1000_sf
# Office (multi-tenant type building)                 1000_sf
# Medical Office                                      1000_sf
# Hotel                                                 rooms
# Daycare (Children)                                  1000_sf
# Destination Retail                                  1000_sf
# Health Club                                         1000_sf
# Academic University                                 1000_sf
# Sit Down/High Turnover Restaurant                   1000_sf
# Supermarket                                         1000_sf
# Museum                                              1000_sf
# Fast Food Restaurant without Drive Through Window   1000_sf
#
# === Unit Conversion Examples ===
# florist: 15,151 sqft → 15.2 1000_sf
# residential: 424,220 sqft → 424.2 DU
# pitch: 296,506 sqft → 6.8 acres
# hostel: 3,004 sqft → 7.5 rooms
# theatre: 49,514 sqft → 6189.3 seats
# school: 152,349 sqft → 1015.7 students
# Saved: data/trip_generators_brooklyn.geojson
# Saved: data/trip_generators_brooklyn.csv
# Saved processed buildings to: data/buildings_brooklyn.geojson
#
# Workflow complete!
